# %% [markdown]
# ## Step 1 - Data Gathering

# %%
# Importing the required libraries
import pandas as pd
import glob

# Specify the path where data files are located
path = r"G:\My Drive\Data Analyst Course\5.1 Introduction to Programming with Python\5.3 Capstone Project -  Introduction to Programming with Python\Sales_Data\Sales2019"

# Use the glob module to get a list of all file names with the extension ".csv" in the specified folder
file_list = glob.glob(path + "\*.csv")

# print the list
print(file_list)
# Out:
# ['G:\\My Drive\\Data Analyst Course\\5.1 Introduction to Programming with Python\\5.3 Capstone Project -  Introduction to Programming with Python\\Sales_Data\\Sales2019\\Sales_April_2019.csv', 'G:\\My Drive\\Data Analyst Course\\5.1 Introduction to Programming with Python\\5.3 Capstone Project -  Introduction to Programming with Python\\Sales_Data\\Sales2019\\Sales_August_2019.csv', 'G:\\My Drive\\Data Analyst Course\\5.1 Introduction to Programming with Python\\5.3 Capstone Project -  Introduction to Programming with Python\\Sales_Data\\Sales2019\\Sales_December_2019.csv', 'G:\\My Drive\\Data Analyst Course\\5.1 Introduction to Programming with Python\\5.3 Capstone Project -  Introduction to Programming with Python\\Sales_Data\\Sales2019\\Sales_February_2019.csv', 'G:\\My Drive\\Data Analyst Course\\5.1 Introduction to Programming with Python\\5.3 Capstone Project -  Introduction to Programming with Python\\Sales_Data\\Sales2019\\Sales_January_2019.csv', 'G:\\My Drive\\Data Analyst Course\\5.1 Introduction to Programming with Python\\5.3 Capstone Project -  Introduction to Programming with Python\\Sales_Data\\Sales2019\\Sales_July_2019.csv', 'G:\\My Drive\\Data Analyst Course\\5.1 Introduction to Programming with Python\\5.3 Capstone Project -  Introduction to Programming with Python\\Sales_Data\\Sales2019\\Sales_June_2019.csv', 'G:\\My Drive\\Data Analyst Course\\5.1 Introduction to Programming with Python\\5.3 Capstone Project -  Introduction to Programming with Python\\Sales_Data\\Sales2019\\Sales_March_2019.csv', 'G:\\My Drive\\Data Analyst Course\\5.1 Introduction to Programming with Python\\5.3 Capstone Project -  Introduction to Programming with Python\\Sales_Data\\Sales2019\\Sales_May_2019.csv', 'G:\\My Drive\\Data Analyst Course\\5.1 Introduction to Programming with Python\\5.3 Capstone Project -  Introduction to Programming with Python\\Sales_Data\\Sales2019\\Sales_November_2019.csv', 'G:\\My Drive\\Data Analyst Course\\5.1 Introduction to Programming with Python\\5.3 Capstone Project -  Introduction to Programming with Python\\Sales_Data\\Sales2019\\Sales_October_2019.csv', 'G:\\My Drive\\Data Analyst Course\\5.1 Introduction to Programming with Python\\5.3 Capstone Project -  Introduction to Programming with Python\\Sales_Data\\Sales2019\\Sales_September_2019.csv']

# %%
# Initialize an empty list to hold all the dataframes
dataframes = []

# Loop through each file, read it as a dataframe, and append it to the list
for file in file_list:
    df = pd.read_csv(file)
    dataframes.append(df)

# Concatenate all the dataframes into one
merged_df = pd.concat(dataframes)

# Save the merged DataFrame as "DataMerged.csv" in your local Google Drive folder
output_path = "G:\\My Drive\\Data Analyst Course\\5.1 Introduction to Programming with Python\\5.3 Capstone Project -  Introduction to Programming with Python\\2019SalesMgd.csv"
merged_df.to_csv(output_path, index=False)

# Print a message to confirm that the data has been merged and saved successfully
print("Data has been merged and saved as 2019SalesMgd.csv in your local Google Drive folder.")
# Out:
# Data has been merged and saved as 2019SalesMgd.csv in your local Google Drive folder.

# %%
#Check the DataMerged file
print(df)
# Out:
#       Order ID                 Product Quantity Ordered Price Each  \
# 0       248151   AA Batteries (4-pack)                4       3.84
# 1       248152    USB-C Charging Cable                2      11.95
# 2       248153    USB-C Charging Cable                1      11.95
# 3       248154        27in FHD Monitor                1     149.99
# 4       248155    USB-C Charging Cable                1      11.95
# ...        ...                     ...              ...        ...
# 11681   259353  AAA Batteries (4-pack)                3       2.99
# 11682   259354                  iPhone                1        700
# 11683   259355                  iPhone                1        700
# 11684   259356  34in Ultrawide Monitor                1     379.99
# 11685   259357    USB-C Charging Cable                1      11.95
#
#            Order Date                         Purchase Address
# 0      09/17/19 14:44      380 North St, Los Angeles, CA 90001
# 1      09/29/19 10:19             511 8th St, Austin, TX 73301
# 2      09/16/19 17:48    151 Johnson St, Los Angeles, CA 90001
# 3      09/27/19 07:52        355 Hickory St, Seattle, WA 98101
# 4      09/01/19 19:03            125 5th St, Atlanta, GA 30301
# ...               ...                                      ...
# 11681  09/17/19 20:56   840 Highland St, Los Angeles, CA 90001
# 11682  09/01/19 16:00  216 Dogwood St, San Francisco, CA 94016
# 11683  09/23/19 07:39     220 12th St, San Francisco, CA 94016
# 11684  09/19/19 17:30   511 Forest St, San Francisco, CA 94016
# 11685  09/30/19 00:18   250 Meadow St, San Francisco, CA 94016
#
# [11686 rows x 6 columns]

# %% [markdown]
# ## Step 2 - Data Cleaning

# %%
# Load the merged data
data_path = "G:\\My Drive\\Data Analyst Course\\5.1 Introduction to Programming with Python\\5.3 Capstone Project -  Introduction to Programming with Python\\2019SalesMgd.csv"
df = pd.read_csv(data_path)

# %%
# Check the shape of the dataframe to see the number of rows and columns
print(df.shape)
# Out:
# (186850, 6)

# %%
# Check for null values in the dataframe
df.isnull().sum()
# Out:
# Order ID            545
# Product             545
# Quantity Ordered    545
# Price Each          545
# Order Date          545
# Purchase Address    545
# dtype: int64

# %%
# Check the rows with NaN value
df[df.isna().any(axis=1)]
# Out:
#        Order ID Product Quantity Ordered Price Each Order Date  \
# 1           NaN     NaN              NaN        NaN        NaN
# 356         NaN     NaN              NaN        NaN        NaN
# 735         NaN     NaN              NaN        NaN        NaN
# 1433        NaN     NaN              NaN        NaN        NaN
# 1553        NaN     NaN              NaN        NaN        NaN
# ...         ...     ...              ...        ...        ...
# 185176      NaN     NaN              NaN        NaN        NaN
# 185438      NaN     NaN              NaN        NaN        NaN
# 186042      NaN     NaN              NaN        NaN        NaN
# 186548      NaN     NaN              NaN        NaN        NaN
# 186826      NaN     NaN              NaN        NaN        NaN
#
#        Purchase Address
# 1                   NaN
# 356                 NaN
# 735                 NaN
# 1433                NaN
# 1553                NaN
# ...                 ...
# 185176              NaN
# 185438              NaN
# 186042              NaN
# 186548              NaN
# 186826              NaN
#
# [545 rows x 6 columns]

# %%
# Drop the NaN
df=df.dropna(how="all")

# %%
df
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# 5        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# 0       04/19/19 08:46             917 1st St, Dallas, TX 75001
# 2       04/07/19 22:30        682 Chestnut St, Boston, MA 02215
# 3       04/12/19 14:38     669 Spruce St, Los Angeles, CA 90001
# 4       04/12/19 14:38     669 Spruce St, Los Angeles, CA 90001
# 5       04/30/19 09:27        333 8th St, Los Angeles, CA 90001
# ...                ...                                      ...
# 186845  09/17/19 20:56   840 Highland St, Los Angeles, CA 90001
# 186846  09/01/19 16:00  216 Dogwood St, San Francisco, CA 94016
# 186847  09/23/19 07:39     220 12th St, San Francisco, CA 94016
# 186848  09/19/19 17:30   511 Forest St, San Francisco, CA 94016
# 186849  09/30/19 00:18   250 Meadow St, San Francisco, CA 94016
#
# [186305 rows x 6 columns]

# %%
# Check the number of rows with missing values (empty lines)
num_empty_lines = df.isnull().all(axis=1).sum()

# If 'num_empty_lines' is greater than 0, it means there are empty lines in the DataFrame.
print("Number of empty lines:", num_empty_lines)
# Out:
# Number of empty lines: 0

# %%
# Check for unnecessary columns.
df.columns
# Out:
# Index(['Order ID', 'Product', 'Quantity Ordered', 'Price Each', 'Order Date',
#        'Purchase Address'],
#       dtype='object')

# %%
# Convert the headers to lower case
df.columns=df.columns.str.lower()

# %%
#Filter the duplicated headers and drop them
filtered = df.loc[df["product"] == "Product"]

# %%
df = df.drop(filtered.index)

# %%
df
# Out:
#        order id                     product quantity ordered price each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# 5        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             order date                         purchase address
# 0       04/19/19 08:46             917 1st St, Dallas, TX 75001
# 2       04/07/19 22:30        682 Chestnut St, Boston, MA 02215
# 3       04/12/19 14:38     669 Spruce St, Los Angeles, CA 90001
# 4       04/12/19 14:38     669 Spruce St, Los Angeles, CA 90001
# 5       04/30/19 09:27        333 8th St, Los Angeles, CA 90001
# ...                ...                                      ...
# 186845  09/17/19 20:56   840 Highland St, Los Angeles, CA 90001
# 186846  09/01/19 16:00  216 Dogwood St, San Francisco, CA 94016
# 186847  09/23/19 07:39     220 12th St, San Francisco, CA 94016
# 186848  09/19/19 17:30   511 Forest St, San Francisco, CA 94016
# 186849  09/30/19 00:18   250 Meadow St, San Francisco, CA 94016
#
# [185950 rows x 6 columns]

# %%
# Check for duplicated rows
print(df.duplicated().sum())
# Out:
# 264

# %%
# Drop any duplicated rows
df = df.drop_duplicates()

# %%
df
# Out:
#        order id                     product quantity ordered price each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# 5        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             order date                         purchase address
# 0       04/19/19 08:46             917 1st St, Dallas, TX 75001
# 2       04/07/19 22:30        682 Chestnut St, Boston, MA 02215
# 3       04/12/19 14:38     669 Spruce St, Los Angeles, CA 90001
# 4       04/12/19 14:38     669 Spruce St, Los Angeles, CA 90001
# 5       04/30/19 09:27        333 8th St, Los Angeles, CA 90001
# ...                ...                                      ...
# 186845  09/17/19 20:56   840 Highland St, Los Angeles, CA 90001
# 186846  09/01/19 16:00  216 Dogwood St, San Francisco, CA 94016
# 186847  09/23/19 07:39     220 12th St, San Francisco, CA 94016
# 186848  09/19/19 17:30   511 Forest St, San Francisco, CA 94016
# 186849  09/30/19 00:18   250 Meadow St, San Francisco, CA 94016
#
# [185686 rows x 6 columns]

# %% [markdown]
# ## Step 3 - Data Preparation

# %% [markdown]
# ### Spliting Address

# %%
# Use .str.split() to split the "purchase address" column into street, city, and state
address_split = df['purchase address'].str.split(',', n=2, expand=True)

# Assign the split values to new columns in the DataFrame
df['street'] = address_split[0].str.strip()
df['city'] = address_split[1].str.strip()
df['state postcode'] = address_split[2].str.strip()
# Out:
# C:\Users\julia_so1gyxp\AppData\Local\Temp\ipykernel_5516\388080531.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['street'] = address_split[0].str.strip()
# C:\Users\julia_so1gyxp\AppData\Local\Temp\ipykernel_5516\388080531.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['city'] = address_split[1].str.strip()
# C:\Users\julia_so1gyxp\AppData\Local\Temp\ipykernel_5516\388080531.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['state postcode'] = address_split[2].str.strip()

# %%
df
# Out:
#        order id                     product quantity ordered price each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# 5        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             order date                         purchase address  \
# 0       04/19/19 08:46             917 1st St, Dallas, TX 75001
# 2       04/07/19 22:30        682 Chestnut St, Boston, MA 02215
# 3       04/12/19 14:38     669 Spruce St, Los Angeles, CA 90001
# 4       04/12/19 14:38     669 Spruce St, Los Angeles, CA 90001
# 5       04/30/19 09:27        333 8th St, Los Angeles, CA 90001
# ...                ...                                      ...
# 186845  09/17/19 20:56   840 Highland St, Los Angeles, CA 90001
# 186846  09/01/19 16:00  216 Dogwood St, San Francisco, CA 94016
# 186847  09/23/19 07:39     220 12th St, San Francisco, CA 94016
# 186848  09/19/19 17:30   511 Forest St, San Francisco, CA 94016
# 186849  09/30/19 00:18   250 Meadow St, San Francisco, CA 94016
#
#                  street           city state postcode
# 0            917 1st St         Dallas       TX 75001
# 2       682 Chestnut St         Boston       MA 02215
# 3         669 Spruce St    Los Angeles       CA 90001
# 4         669 Spruce St    Los Angeles       CA 90001
# 5            333 8th St    Los Angeles       CA 90001
# ...                 ...            ...            ...
# 186845  840 Highland St    Los Angeles       CA 90001
# 186846   216 Dogwood St  San Francisco       CA 94016
# 186847      220 12th St  San Francisco       CA 94016
# 186848    511 Forest St  San Francisco       CA 94016
# 186849    250 Meadow St  San Francisco       CA 94016
#
# [185686 rows x 9 columns]

# %%
# Extract from State the postcode into a new column
df[['state', 'postcode']] = df['state postcode'].str.extract(r'([A-Za-z]+) (\d+)', expand=True)
# Out:
# C:\Users\julia_so1gyxp\AppData\Local\Temp\ipykernel_5516\3698211878.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['state', 'postcode']] = df['state postcode'].str.extract(r'([A-Za-z]+) (\d+)', expand=True)
# C:\Users\julia_so1gyxp\AppData\Local\Temp\ipykernel_5516\3698211878.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['state', 'postcode']] = df['state postcode'].str.extract(r'([A-Za-z]+) (\d+)', expand=True)

# %%
df
# Out:
#        order id                     product quantity ordered price each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# 5        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             order date                         purchase address  \
# 0       04/19/19 08:46             917 1st St, Dallas, TX 75001
# 2       04/07/19 22:30        682 Chestnut St, Boston, MA 02215
# 3       04/12/19 14:38     669 Spruce St, Los Angeles, CA 90001
# 4       04/12/19 14:38     669 Spruce St, Los Angeles, CA 90001
# 5       04/30/19 09:27        333 8th St, Los Angeles, CA 90001
# ...                ...                                      ...
# 186845  09/17/19 20:56   840 Highland St, Los Angeles, CA 90001
# 186846  09/01/19 16:00  216 Dogwood St, San Francisco, CA 94016
# 186847  09/23/19 07:39     220 12th St, San Francisco, CA 94016
# 186848  09/19/19 17:30   511 Forest St, San Francisco, CA 94016
# 186849  09/30/19 00:18   250 Meadow St, San Francisco, CA 94016
#
#                  street           city state postcode state postcode
# 0            917 1st St         Dallas       TX 75001    TX    75001
# 2       682 Chestnut St         Boston       MA 02215    MA    02215
# 3         669 Spruce St    Los Angeles       CA 90001    CA    90001
# 4         669 Spruce St    Los Angeles       CA 90001    CA    90001
# 5            333 8th St    Los Angeles       CA 90001    CA    90001
# ...                 ...            ...            ...   ...      ...
# 186845  840 Highland St    Los Angeles       CA 90001    CA    90001
# 186846   216 Dogwood St  San Francisco       CA 94016    CA    94016
# 186847      220 12th St  San Francisco       CA 94016    CA    94016
# 186848    511 Forest St  San Francisco       CA 94016    CA    94016
# 186849    250 Meadow St  San Francisco       CA 94016    CA    94016
#
# [185686 rows x 11 columns]

# %%
# Concatenate 'city' and 'state' columns with a space in between to get 'city state'
df['city'] = df['city'] + ' ' + df['state']
# Out:
# C:\Users\julia_so1gyxp\AppData\Local\Temp\ipykernel_5516\2922896562.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['city'] = df['city'] + ' ' + df['state']

# %%
df
# Out:
#        order id                     product quantity ordered price each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# 5        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             order date                         purchase address  \
# 0       04/19/19 08:46             917 1st St, Dallas, TX 75001
# 2       04/07/19 22:30        682 Chestnut St, Boston, MA 02215
# 3       04/12/19 14:38     669 Spruce St, Los Angeles, CA 90001
# 4       04/12/19 14:38     669 Spruce St, Los Angeles, CA 90001
# 5       04/30/19 09:27        333 8th St, Los Angeles, CA 90001
# ...                ...                                      ...
# 186845  09/17/19 20:56   840 Highland St, Los Angeles, CA 90001
# 186846  09/01/19 16:00  216 Dogwood St, San Francisco, CA 94016
# 186847  09/23/19 07:39     220 12th St, San Francisco, CA 94016
# 186848  09/19/19 17:30   511 Forest St, San Francisco, CA 94016
# 186849  09/30/19 00:18   250 Meadow St, San Francisco, CA 94016
#
#                  street              city state postcode state postcode
# 0            917 1st St         Dallas TX       TX 75001    TX    75001
# 2       682 Chestnut St         Boston MA       MA 02215    MA    02215
# 3         669 Spruce St    Los Angeles CA       CA 90001    CA    90001
# 4         669 Spruce St    Los Angeles CA       CA 90001    CA    90001
# 5            333 8th St    Los Angeles CA       CA 90001    CA    90001
# ...                 ...               ...            ...   ...      ...
# 186845  840 Highland St    Los Angeles CA       CA 90001    CA    90001
# 186846   216 Dogwood St  San Francisco CA       CA 94016    CA    94016
# 186847      220 12th St  San Francisco CA       CA 94016    CA    94016
# 186848    511 Forest St  San Francisco CA       CA 94016    CA    94016
# 186849    250 Meadow St  San Francisco CA       CA 94016    CA    94016
#
# [185686 rows x 11 columns]

# %%
# Drop the unnecessary columns
df.drop(['purchase address', 'state postcode'], axis=1, inplace=True)
# Out:
# C:\Users\julia_so1gyxp\AppData\Local\Temp\ipykernel_5516\2014880907.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(['purchase address', 'state postcode'], axis=1, inplace=True)

# %%
df
# Out:
#        order id                     product quantity ordered price each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# 5        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             order date           street              city state postcode
# 0       04/19/19 08:46       917 1st St         Dallas TX    TX    75001
# 2       04/07/19 22:30  682 Chestnut St         Boston MA    MA    02215
# 3       04/12/19 14:38    669 Spruce St    Los Angeles CA    CA    90001
# 4       04/12/19 14:38    669 Spruce St    Los Angeles CA    CA    90001
# 5       04/30/19 09:27       333 8th St    Los Angeles CA    CA    90001
# ...                ...              ...               ...   ...      ...
# 186845  09/17/19 20:56  840 Highland St    Los Angeles CA    CA    90001
# 186846  09/01/19 16:00   216 Dogwood St  San Francisco CA    CA    94016
# 186847  09/23/19 07:39      220 12th St  San Francisco CA    CA    94016
# 186848  09/19/19 17:30    511 Forest St  San Francisco CA    CA    94016
# 186849  09/30/19 00:18    250 Meadow St  San Francisco CA    CA    94016
#
# [185686 rows x 9 columns]

# %% [markdown]
# ### Correcting and Extracting data from Order Date

# %%
df.dtypes
# Out:
# order id            object
# product             object
# quantity ordered    object
# price each          object
# order date          object
# street              object
# city                object
# state               object
# postcode            object
# dtype: object

# %%
#Convert "Order Date" to the correct data type
df['order date'] = pd.to_datetime(df['order date'], format='%m/%d/%y %H:%M')
# Out:
# C:\Users\julia_so1gyxp\AppData\Local\Temp\ipykernel_5516\1464299054.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['order date'] = pd.to_datetime(df['order date'], format='%m/%d/%y %H:%M')

# %%
# Extract date-related information
df['month'] = df['order date'].dt.strftime('%B')
df['weekday'] = df['order date'].dt.strftime('%A')
df['hour'] = df['order date'].dt.strftime('%H:%M')
# Out:
# C:\Users\julia_so1gyxp\AppData\Local\Temp\ipykernel_5516\2259384225.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['month'] = df['order date'].dt.strftime('%B')
# C:\Users\julia_so1gyxp\AppData\Local\Temp\ipykernel_5516\2259384225.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['weekday'] = df['order date'].dt.strftime('%A')
# C:\Users\julia_so1gyxp\AppData\Local\Temp\ipykernel_5516\2259384225.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['hour'] = df['order date'].dt.strftime('%H:%M')

# %%
df
# Out:
#        order id                     product quantity ordered price each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# 5        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#                 order date           street              city state postcode  \
# 0      2019-04-19 08:46:00       917 1st St         Dallas TX    TX    75001
# 2      2019-04-07 22:30:00  682 Chestnut St         Boston MA    MA    02215
# 3      2019-04-12 14:38:00    669 Spruce St    Los Angeles CA    CA    90001
# 4      2019-04-12 14:38:00    669 Spruce St    Los Angeles CA    CA    90001
# 5      2019-04-30 09:27:00       333 8th St    Los Angeles CA    CA    90001
# ...                    ...              ...               ...   ...      ...
# 186845 2019-09-17 20:56:00  840 Highland St    Los Angeles CA    CA    90001
# 186846 2019-09-01 16:00:00   216 Dogwood St  San Francisco CA    CA    94016
# 186847 2019-09-23 07:39:00      220 12th St  San Francisco CA    CA    94016
# 186848 2019-09-19 17:30:00    511 Forest St  San Francisco CA    CA    94016
# 186849 2019-09-30 00:18:00    250 Meadow St  San Francisco CA    CA    94016
#
#             month   weekday   hour
# 0           April    Friday  08:46
# 2           April    Sunday  22:30
# 3           April    Friday  14:38
# 4           April    Friday  14:38
# 5           April   Tuesday  09:27
# ...           ...       ...    ...
# 186845  September   Tuesday  20:56
# 186846  September    Sunday  16:00
# 186847  September    Monday  07:39
# 186848  September  Thursday  17:30
# 186849  September    Monday  00:18
#
# [185686 rows x 12 columns]

# %%
# Add a new column 'hour_only' containing only the hour part from the 'hour' column
df['hour_only'] = df['hour'].str[:2]
# Out:
# C:\Users\julia_so1gyxp\AppData\Local\Temp\ipykernel_5516\3192630863.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['hour_only'] = df['hour'].str[:2]

# %%
df
# Out:
#        order id                     product quantity ordered price each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# 5        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#                 order date           street              city state postcode  \
# 0      2019-04-19 08:46:00       917 1st St         Dallas TX    TX    75001
# 2      2019-04-07 22:30:00  682 Chestnut St         Boston MA    MA    02215
# 3      2019-04-12 14:38:00    669 Spruce St    Los Angeles CA    CA    90001
# 4      2019-04-12 14:38:00    669 Spruce St    Los Angeles CA    CA    90001
# 5      2019-04-30 09:27:00       333 8th St    Los Angeles CA    CA    90001
# ...                    ...              ...               ...   ...      ...
# 186845 2019-09-17 20:56:00  840 Highland St    Los Angeles CA    CA    90001
# 186846 2019-09-01 16:00:00   216 Dogwood St  San Francisco CA    CA    94016
# 186847 2019-09-23 07:39:00      220 12th St  San Francisco CA    CA    94016
# 186848 2019-09-19 17:30:00    511 Forest St  San Francisco CA    CA    94016
# 186849 2019-09-30 00:18:00    250 Meadow St  San Francisco CA    CA    94016
#
#             month   weekday   hour hour_only
# 0           April    Friday  08:46        08
# 2           April    Sunday  22:30        22
# 3           April    Friday  14:38        14
# 4           April    Friday  14:38        14
# 5           April   Tuesday  09:27        09
# ...           ...       ...    ...       ...
# 186845  September   Tuesday  20:56        20
# 186846  September    Sunday  16:00        16
# 186847  September    Monday  07:39        07
# 186848  September  Thursday  17:30        17
# 186849  September    Monday  00:18        00
#
# [185686 rows x 13 columns]

# %%
# Extract dyear from order date
df['year'] = df['order date'].dt.year
# Out:
# C:\Users\julia_so1gyxp\AppData\Local\Temp\ipykernel_5516\4183608318.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['year'] = df['order date'].dt.year

# %%
df
# Out:
#        order id                     product quantity ordered price each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# 5        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#                 order date           street              city state postcode  \
# 0      2019-04-19 08:46:00       917 1st St         Dallas TX    TX    75001
# 2      2019-04-07 22:30:00  682 Chestnut St         Boston MA    MA    02215
# 3      2019-04-12 14:38:00    669 Spruce St    Los Angeles CA    CA    90001
# 4      2019-04-12 14:38:00    669 Spruce St    Los Angeles CA    CA    90001
# 5      2019-04-30 09:27:00       333 8th St    Los Angeles CA    CA    90001
# ...                    ...              ...               ...   ...      ...
# 186845 2019-09-17 20:56:00  840 Highland St    Los Angeles CA    CA    90001
# 186846 2019-09-01 16:00:00   216 Dogwood St  San Francisco CA    CA    94016
# 186847 2019-09-23 07:39:00      220 12th St  San Francisco CA    CA    94016
# 186848 2019-09-19 17:30:00    511 Forest St  San Francisco CA    CA    94016
# 186849 2019-09-30 00:18:00    250 Meadow St  San Francisco CA    CA    94016
#
#             month   weekday   hour hour_only  year
# 0           April    Friday  08:46        08  2019
# 2           April    Sunday  22:30        22  2019
# 3           April    Friday  14:38        14  2019
# 4           April    Friday  14:38        14  2019
# 5           April   Tuesday  09:27        09  2019
# ...           ...       ...    ...       ...   ...
# 186845  September   Tuesday  20:56        20  2019
# 186846  September    Sunday  16:00        16  2019
# 186847  September    Monday  07:39        07  2019
# 186848  September  Thursday  17:30        17  2019
# 186849  September    Monday  00:18        00  2019
#
# [185686 rows x 14 columns]

# %%
# check the years present on DataFrame
unique_years = df['year'].unique()
print(unique_years)
# Out:
# [2019 2020]

# %%
# Filter rows where 'year' is not equal to 2020
df_filtered = df.loc[df['year'] != 2020]

# %%
# Drop rows where 'year' is equal to 2020 from the original dataframe
df.drop(df[df['year'] == 2020].index, inplace=True)
# Out:
# C:\Users\julia_so1gyxp\AppData\Local\Temp\ipykernel_5516\3060669193.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(df[df['year'] == 2020].index, inplace=True)

# %%
# check the years present on DataFrame
unique_years = df['year'].unique()
print(unique_years)
# Out:
# [2019]

# %%
# Combine 'month' and 'year' columns into a new 'month_year' column
df['month_year'] = df['month'].astype(str) + '_' + df['year'].astype(str)
# Out:
# C:\Users\julia_so1gyxp\AppData\Local\Temp\ipykernel_5516\766916535.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['month_year'] = df['month'].astype(str) + '_' + df['year'].astype(str)

# %%
df
# Out:
#        order id                     product quantity ordered price each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# 5        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#                 order date           street              city state postcode  \
# 0      2019-04-19 08:46:00       917 1st St         Dallas TX    TX    75001
# 2      2019-04-07 22:30:00  682 Chestnut St         Boston MA    MA    02215
# 3      2019-04-12 14:38:00    669 Spruce St    Los Angeles CA    CA    90001
# 4      2019-04-12 14:38:00    669 Spruce St    Los Angeles CA    CA    90001
# 5      2019-04-30 09:27:00       333 8th St    Los Angeles CA    CA    90001
# ...                    ...              ...               ...   ...      ...
# 186845 2019-09-17 20:56:00  840 Highland St    Los Angeles CA    CA    90001
# 186846 2019-09-01 16:00:00   216 Dogwood St  San Francisco CA    CA    94016
# 186847 2019-09-23 07:39:00      220 12th St  San Francisco CA    CA    94016
# 186848 2019-09-19 17:30:00    511 Forest St  San Francisco CA    CA    94016
# 186849 2019-09-30 00:18:00    250 Meadow St  San Francisco CA    CA    94016
#
#             month   weekday   hour hour_only  year      month_year
# 0           April    Friday  08:46        08  2019      April_2019
# 2           April    Sunday  22:30        22  2019      April_2019
# 3           April    Friday  14:38        14  2019      April_2019
# 4           April    Friday  14:38        14  2019      April_2019
# 5           April   Tuesday  09:27        09  2019      April_2019
# ...           ...       ...    ...       ...   ...             ...
# 186845  September   Tuesday  20:56        20  2019  September_2019
# 186846  September    Sunday  16:00        16  2019  September_2019
# 186847  September    Monday  07:39        07  2019  September_2019
# 186848  September  Thursday  17:30        17  2019  September_2019
# 186849  September    Monday  00:18        00  2019  September_2019
#
# [185652 rows x 15 columns]

# %% [markdown]
# ### Calculations

# %%
#convert "price each" to a correct data type
df['price each'] = df['price each'].astype(float)
# Out:
# C:\Users\julia_so1gyxp\AppData\Local\Temp\ipykernel_5516\3794898983.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price each'] = df['price each'].astype(float)

# %%
# Calculate Revenue
df["revenue"]=df["price each"] * df["quantity ordered"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\ops\array_ops.py:165, in _na_arithmetic_op(left, right, op, is_cmp)
#     164 try:
# --> 165     result = func(left, right)
#     166 except TypeError:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:241, in evaluate(op, a, b, use_numexpr)
#     239     if use_numexpr:
#     240         # error: "None" not callable
# --> 241         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     242 return _evaluate_standard(op, op_str, a, b)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:129, in _evaluate_numexpr(op, op_str, a, b)
#     128 if result is None:
# --> 129     result = _evaluate_standard(op, op_str, a, b)
#     131 return result
#
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:70, in _evaluate_standard(op, op_str, a, b)
#      69     _store_test_result(False)
# ---> 70 return op(a, b)
#
# TypeError: can't multiply sequence by non-int of type 'float'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 2
#       1 # Calculate Revenue
# ----> 2 df["revenue"]=df["price each"] * df["quantity ordered"]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\ops\common.py:72, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      68             return NotImplemented
#      70 other = item_from_zerodim(other)
# ---> 72 return method(self, other)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\arraylike.py:118, in OpsMixin.__mul__(self, other)
#     116 @unpack_zerodim_and_defer("__mul__")
#     117 def __mul__(self, other):
# --> 118     return self._arith_method(other, operator.mul)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:6259, in Series._arith_method(self, other, op)
#    6257 def _arith_method(self, other, op):
#    6258     self, other = ops.align_method_SERIES(self, other)
# -> 6259     return base.IndexOpsMixin._arith_method(self, other, op)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\base.py:1325, in IndexOpsMixin._arith_method(self, other, op)
#    1322 rvalues = ensure_wrapped_if_datetimelike(rvalues)
#    1324 with np.errstate(all="ignore"):
# -> 1325     result = ops.arithmetic_op(lvalues, rvalues, op)
#    1327 return self._construct_result(result, name=res_name)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\ops\array_ops.py:226, in arithmetic_op(left, right, op)
#     222     _bool_arith_check(op, left, right)
#     224     # error: Argument 1 to "_na_arithmetic_op" has incompatible type
#     225     # "Union[ExtensionArray, ndarray[Any, Any]]"; expected "ndarray[Any, Any]"
# --> 226     res_values = _na_arithmetic_op(left, right, op)  # type: ignore[arg-type]
#     228 return res_values
#
# File ~\anaconda3\Lib\site-packages\pandas\core\ops\array_ops.py:172, in _na_arithmetic_op(left, right, op, is_cmp)
#     166 except TypeError:
#     167     if not is_cmp and (is_object_dtype(left.dtype) or is_object_dtype(right)):
#     168         # For object dtype, fallback to a masked operation (only operating
#     169         #  on the non-missing values)
#     170         # Don't do this for comparisons, as that will handle complex numbers
#     171         #  incorrectly, see GH#32047
# --> 172         result = _masked_arith_op(left, right, op)
#     173     else:
#     174         raise
#
# File ~\anaconda3\Lib\site-packages\pandas\core\ops\array_ops.py:110, in _masked_arith_op(x, y, op)
#     108     # See GH#5284, GH#5035, GH#19448 for historical reference
#     109     if mask.any():
# --> 110         result[mask] = op(xrav[mask], yrav[mask])
#     112 else:
#     113     if not is_scalar(y):
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
# Check data type
print(df['price each'].dtype)
print(df['quantity ordered'].dtype)
# Out:
# float64
# object

# %%
# Convert the 'quantity ordered' column to numeric data type, replacing non-numeric values with NaN
df['quantity ordered'] = pd.to_numeric(df['quantity ordered'], errors='coerce')
# Out:
# C:\Users\julia_so1gyxp\AppData\Local\Temp\ipykernel_5516\2326390856.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['quantity ordered'] = pd.to_numeric(df['quantity ordered'], errors='coerce')

# %%
# Drop rows with missing values in 'quantity ordered'
df.dropna(subset=['quantity ordered'], inplace=True)
# Out:
# C:\Users\julia_so1gyxp\AppData\Local\Temp\ipykernel_5516\3964171572.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(subset=['quantity ordered'], inplace=True)

# %%
# Check data type
print(df['price each'].dtype)
print(df['quantity ordered'].dtype)
# Out:
# float64
# int64

# %%
# Calculate Revenue
df["revenue"]=df["price each"] * df["quantity ordered"]
# Out:
# C:\Users\julia_so1gyxp\AppData\Local\Temp\ipykernel_5516\1335692813.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["revenue"]=df["price each"] * df["quantity ordered"]

# %%
# Check if 'df' has any empty cells (NaN values)
has_empty_cells = df.isna().any().any()
print(has_empty_cells)
# Out:
# False

# %%
# Check the shape of the dataframe to see the number of rows and columns
print(df.shape)
# Out:
# (185652, 16)

# %% [markdown]
# ## Saving the changes made into Merged File

# %%
# Save the changes back to 'DataMerged.csv'
output_path = "G:\\My Drive\\Data Analyst Course\\5.1 Introduction to Programming with Python\\5.3 Capstone Project -  Introduction to Programming with Python\\2019SalesMgd.csv"
df.to_csv(output_path, index=False)
